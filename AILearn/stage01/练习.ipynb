# %%
a, b = 10, 10

# %%
a

# %%
range

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 1, 0.01)
plt.plot(t, t, t, t * t, t, t * t * t)

# %%
# %who

# %% [markdown]
# ## 自动执行

# %%
def adder(a, b):
    return a + b

# %%
adder(1, 2)
